# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('BirdsRecordingAsia.csv')
df.head()
# Out:
#        id         gen             sp  ssp  group                en  \
# 0  335628  Megapodius  nicobariensis  NaN  birds  Nicobar Megapode
# 1  298956  Megapodius  nicobariensis  NaN  birds  Nicobar Megapode
# 2  569023       Lerwa          lerwa  NaN  birds    Snow Partridge
# 3  426652       Lerwa          lerwa  NaN  birds    Snow Partridge
# 4  426650       Lerwa          lerwa  NaN  birds    Snow Partridge
#
#                 rec    cnt                                 loc        lat  \
# 0       Sudhir Garg  India                                 NaN        NaN
# 1     Garima Bhatia  India                                 NaN        NaN
# 2  Jelle Scharringa  India  Sela pass area, Arrunachal Pradesh  27.492800
# 3     Peter Boesman  India  Sela pass area, Arrunachal Pradesh  27.492778
# 4     Peter Boesman  India  Sela pass area, Arrunachal Pradesh  27.492778
#
#    ...                                                rmk bird-seen  \
# ...

# %%
df.shape
# Out:
# (2020, 38)

# %%
df.dtypes
# Out:
# id                 int64
# gen               object
# sp                object
# ssp               object
# group             object
# en                object
# rec               object
# cnt               object
# loc               object
# lat              float64
# lng              float64
# alt               object
# type              object
# sex               object
# stage             object
# method            object
# url               object
# file              object
# file-name         object
# sono              object
# osci              object
# lic               object
# q                 object
# length            object
# time              object
# date              object
# uploaded          object
# also              object
# rmk               object
# bird-seen         object
# animal-seen       object
# playback-used     object
# temp             float64
# regnr            float64
# auto              object
# dvc               object
# mic               object
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# gen                 0
# sp                  0
# ssp              1707
# group               1
# en                  0
# rec                 0
# cnt                 0
# loc                36
# lat               117
# lng               117
# alt               116
# type               28
# sex              1692
# stage            1801
# method              0
# url                 0
# file               36
# file-name          36
# sono                0
# osci                0
# lic                 0
# q                   0
# length              0
# time                4
# date                0
# uploaded            0
# also                0
# rmk              1145
# bird-seen           0
# animal-seen         0
# playback-used       0
# temp             2020
# regnr            2019
# auto                0
# dvc              2003
# mic              2007
# smp                 0
# dtype: int64

# %%
df1 = df[df.groupby('sp').gen.transform('count')>25].copy()

# %%
df1.shape
# Out:
# (463, 38)

# %%
df1.head()
# Out:
#         id          gen           sp          ssp  group               en  \
# 13  676586  Francolinus  francolinus          NaN  birds  Black Francolin
# 14  569064  Francolinus  francolinus          NaN  birds  Black Francolin
# 15  426552  Francolinus  francolinus          NaN  birds  Black Francolin
# 16  426551  Francolinus  francolinus          NaN  birds  Black Francolin
# 17  362925  Francolinus  francolinus  melanonotus  birds  Black Francolin
#
#                   rec    cnt  \
# 13   Jelle Scharringa  India
# 14   Jelle Scharringa  India
# 15      Peter Boesman  India
# 16      Peter Boesman  India
# 17  Paul J Willoughby  India
#
#                                                   loc        lat  ...  \
# 13                            Baranda, Kutch, Gujarat  23.543500  ...
# 14  Lala-Naliya Grassland Reserve, Kutch, Gujarat ...  23.543500  ...
# 15                         Manas National Park, Assam  26.672638  ...
# ...

# %%
df1.to_csv('BirdRecordingAsia_final.csv')

# %%
train_df= df1[["sp","file"]]

# %%
train_df.head()
# Out:
#              sp                                    file
# 13  francolinus  https://xeno-canto.org/676586/download
# 14  francolinus  https://xeno-canto.org/569064/download
# 15  francolinus  https://xeno-canto.org/426552/download
# 16  francolinus  https://xeno-canto.org/426551/download
# 17  francolinus  https://xeno-canto.org/362925/download

# %%
train_df['sp'].value_counts()
# Out:
# sonneratii       66
# pondicerianus    53
# torqueola        49
# impejanus        36
# gallus           32
# francolinus      31
# lafayettii       31
# spadicea         30
# bicalcarata      29
# asiaticus        28
# cristatus        26
# ceylonensis      26
# melanurus        26
# Name: sp, dtype: int64

# %%
import os
from requests import get
import random

# %%
# os.mkdir('SouthAsia_Recordings/sonneratii')
# os.mkdir('SouthAsia_Recordings/pondicerianus')
# os.mkdir('SouthAsia_Recordings/torqueola')
# os.mkdir('SouthAsia_Recordings/cristatus')
# os.mkdir('SouthAsia_Recordings/spadicea')
# os.mkdir('SouthAsia_Recordings/impejanus')
# os.mkdir('SouthAsia_Recordings/gallus')
# os.mkdir('SouthAsia_Recordings/francolinus')
# os.mkdir('SouthAsia_Recordings/lafayettii')
# os.mkdir('SouthAsia_Recordings/bicalcarata')
# os.mkdir('SouthAsia_Recordings/asiaticus')
# os.mkdir('SouthAsia_Recordings/ceylonensis')
# os.mkdir('SouthAsia_Recordings/melanurus')

# %%
def download(url,dir): 
  name = random.randrange(1, 99999) 
  file_name = dir+"/"+ str(name) + ".mp3"     
  with open(file_name, "wb") as file:
    response = get(url)
    file.write(response.content)

# %%
for x,y in zip(train_df['sp'],train_df['file']):
    if x == 'sonneratii':
        path = 'SouthAsia_Recordings/sonneratii'
        download(y,path)
    elif x=='pondicerianus':
        path = 'SouthAsia_Recordings/pondicerianus'
        download(y,path)
    elif x=='torqueola':
        path = 'SouthAsia_Recordings/torqueola'
        download(y,path)
    elif x=='cristatus':
        path = 'SouthAsia_Recordings/cristatus'
        download(y,path)
    elif x=='spadicea':
        path = 'SouthAsia_Recordings/spadicea'
        download(y,path)
    elif x=='impejanus':
        path = 'SouthAsia_Recordings/impejanus'
        download(y,path)
    elif x=='gallus':
        path = 'SouthAsia_Recordings/gallus'
        download(y,path)
    elif x=='francolinus':
        path = 'SouthAsia_Recordings/francolinus'
        download(y,path)
    elif x=='lafayettii':
        path = 'SouthAsia_Recordings/lafayettii'
        download(y,path)
    elif x=='bicalcarata':
        path = 'SouthAsia_Recordings/bicalcarata'
        download(y,path)
    elif x=='asiaticus':
        path = 'SouthAsia_Recordings/asiaticus'
        download(y,path)
    elif x=='ceylonensis':
        path = 'SouthAsia_Recordings/ceylonensis'
        download(y,path)
    elif x=='melanurus':
        path = 'SouthAsia_Recordings/melanurus'
        download(y,path)
    else:
        print("Invalid Species")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:96, in create_connection(address, timeout, source_address, socket_options)
#      95 if err is not None:
# ---> 96     raise err
#      98 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:86, in create_connection(address, timeout, source_address, socket_options)
#      85     sock.bind(source_address)
# ---> 86 sock.connect(sa)
#      87 return sock
#
# ...
